# %% [markdown]
# # Tempo Segmentation Parameter Fitting
#
# Use this notebook to tune `TempoSegmentationParams` against aligned performance data.
# Will need more data until further testing.

# %% [markdown]
# ## Dataset Format
#
# Provide a JSON array where each entry describes one recording pair:
#
# ```json
# [
#   {
#     "title": "My Recording",
#     "actual": "../scores/reference.scoredata",
#     "played": "../performances/take1.midi",
#     "sections": [
#       { "end_ind": 120, "label": "intro" },
#       { "end_ind": 268, "label": "verse" },
#       { "end_ind": 410, "label": "coda" }
#     ]
#   }
# ]
# ```
#
# * `actual` points to a `.scoredata` protobuf or a reference `.midi` file.
# * `played` is the performed `.midi` file.
# * `sections` is an ordered list. Each `end_ind` is the inclusive index of the final
#   reference note in that tempo segment. The first segment begins at `0`; each
#   subsequent segment starts at the previous end index plus one. The final section must
#   end at the last reference note index.

# %%
from __future__ import annotations

import itertools
import json
import sys
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, List, Sequence, Tuple
from bisect import bisect_right

import numpy as np

NOTEBOOK_DIR = Path.cwd().resolve()
BACKEND_ROOT = NOTEBOOK_DIR.parents[2]
SRC_ROOT = BACKEND_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from scoring import (
    scoring_native,
    analyze_tempo,
    extract_midi_notes,
    extract_pb_notes,
)
from scoring.edit_distance import find_ops
from scoring.notes_pb2 import NoteList, TempoSection
# Out:
# /Users/timothyliu/PycharmProjects/note/backend/.venv/lib/python3.13/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
DATA_PATH = Path("fit_tempo_dataset.json")
assert DATA_PATH.exists(), f"Dataset config not found: {DATA_PATH}"
with DATA_PATH.open("r", encoding="utf-8") as handle:
    raw_entries = json.load(handle)
assert isinstance(raw_entries, list) and raw_entries, (
    "Dataset must be a non-empty list."
)
len(raw_entries)
# Out:
# 1

# %%
@dataclass
class TempoDataset:
    title: str
    actual_times: List[float]
    played_times: List[float]
    aligned_pairs: List[Tuple[int, int]]
    boundaries: List[int]
    segments: List[Tuple[int, int, str]]
    reference_segments: List[Tuple[int, int, str]]
    aligned_actual_indices: List[int]

    @property
    def note_count(self) -> int:
        return len(self.actual_times)

    @property
    def alignment_count(self) -> int:
        return len(self.aligned_pairs)

    @property
    def reference_boundaries(self) -> List[int]:
        return [end for _, end, _ in self.reference_segments[:-1]]


def resolve_path(base: Path, raw: str) -> Path:
    path = Path(raw)
    if not path.is_absolute():
        path = (base / path).resolve()
    return path


def load_note_list(path: Path) -> NoteList:
    suffix = path.suffix.lower()
    if suffix in {".scoredata", ".pb"}:
        return extract_pb_notes(path.read_bytes())
    if suffix in {".midi", ".mid"}:
        return extract_midi_notes(str(path))
    raise ValueError(f"Unsupported note format: {path}")


def compute_alignment(
    actual_list: NoteList, played_list: NoteList
) -> List[Tuple[int, int]]:
    _, aligned = find_ops(actual_list.notes, played_list.notes)
    aligned_sorted = sorted((int(a), int(b)) for a, b in aligned)
    return aligned_sorted


def to_time_list(note_list: NoteList) -> List[float]:
    return [float(note.start_time) for note in note_list.notes]


def parse_sections(
    sections: Sequence[Dict[str, object]],
    aligned_actual_indices: Sequence[int],
) -> Tuple[List[Tuple[int, int, str]], List[int], List[Tuple[int, int, str]]]:
    if not sections:
        raise ValueError("Sections list may not be empty.")
    if not aligned_actual_indices:
        raise ValueError("Cannot derive sections without any aligned notes.")

    segments_aligned: List[Tuple[int, int, str]] = []
    reference_segments: List[Tuple[int, int, str]] = []
    prev_actual_end = -1
    prev_aligned_end = -1

    for idx, raw in enumerate(sections):
        end_actual = int(raw["end_ind"])
        label = str(raw.get("label", f"section_{idx}"))
        if end_actual < 0:
            raise ValueError("Section end index must be non-negative.")
        if end_actual < prev_actual_end:
            raise ValueError("Section end indices must be non-decreasing.")

        aligned_pos = bisect_right(aligned_actual_indices, end_actual) - 1
        if aligned_pos < 0:
            raise ValueError(
                f"Section end index {end_actual} precedes all aligned reference notes."
            )
        if aligned_pos <= prev_aligned_end:
            raise ValueError(
                f"Alignment collapsed segment '{label}' (end {end_actual}) to a non-increasing index."
            )

        start_actual = prev_actual_end + 1
        start_aligned = prev_aligned_end + 1
        segments_aligned.append((start_aligned, aligned_pos, label))
        reference_segments.append((start_actual, end_actual, label))

        prev_actual_end = end_actual
        prev_aligned_end = aligned_pos

    expected_final = len(aligned_actual_indices) - 1
    if prev_aligned_end > expected_final:
        raise ValueError(
            f"Final section exceeded aligned index {expected_final}, got {prev_aligned_end}."
        )

    boundaries = [segment[1] for segment in segments_aligned[:-1]]
    return segments_aligned, boundaries, reference_segments


def build_dataset(entry: Dict[str, object], base_dir: Path) -> TempoDataset:
    title = str(entry.get("title", "Untitled"))
    actual_path = resolve_path(base_dir, entry["actual"])
    played_path = resolve_path(base_dir, entry["played"])
    actual_notes = load_note_list(actual_path)
    played_notes = load_note_list(played_path)
    aligned_pairs = compute_alignment(actual_notes, played_notes)
    aligned_actual_indices = [idx for idx, _ in aligned_pairs]
    segments, boundaries, reference_segments = parse_sections(
        entry["sections"], aligned_actual_indices
    )
    return TempoDataset(
        title=title,
        actual_times=to_time_list(actual_notes),
        played_times=to_time_list(played_notes),
        aligned_pairs=aligned_pairs,
        boundaries=boundaries,
        segments=segments,
        reference_segments=reference_segments,
        aligned_actual_indices=aligned_actual_indices,
    )

# %%
datasets: List[TempoDataset] = []
for entry in raw_entries:
    print(path := DATA_PATH.absolute().parent.parent)
    datasets.append(build_dataset(entry, path))

for ds in datasets:
    aligned_summary = [f"{label}:{start}-{end}" for start, end, label in ds.segments]
    reference_summary = [
        f"{label}:{start}-{end}" for start, end, label in ds.reference_segments
    ]
    print(
        f"{ds.title}: ref_notes={ds.note_count}, aligned={ds.alignment_count}, "
        f"boundaries={ds.boundaries}, ref_boundaries={ds.reference_boundaries}"
    )
    print("  aligned segments ->", aligned_summary)
    print("  reference segments ->", reference_summary)
len(datasets)
# Out:
# 2025-09-28 15:51:06.058 | INFO     | scoring.edit_distance:find_ops:139 - 	[preprocess] took 2.178 ms
# /Users/timothyliu/PycharmProjects/note/backend/resources
# 2025-09-28 15:51:07.104 | INFO     | scoring.edit_distance:find_ops:140 - 	[edit_distance] took 1046.102 ms
# 2025-09-28 15:51:07.107 | INFO     | scoring.edit_distance:find_ops:142 - 	[postprocess] took 1.975 ms
# Spider Dance Take 1: ref_notes=1774, aligned=1563, boundaries=[405, 699, 1239], ref_boundaries=[413, 744, 1381]
#   aligned segments -> ['intro:0-405', 'difficult chorus:406-699', 'bridge:700-1239', 'chorus:1240-1410']
#   reference segments -> ['intro:0-413', 'difficult chorus:414-744', 'bridge:745-1381', 'chorus:1382-1574']
# 1

# %%
def boundaries_from_sections(
    sections: Sequence[TempoSection],
    aligned_actual_indices: Sequence[int],
) -> List[int]:
    if not sections:
        return []
    if not aligned_actual_indices:
        raise ValueError("Cannot map tempo sections without aligned note indices.")

    boundaries: List[int] = []
    for section in sections[:-1]:
        end_actual = getattr(section, "end_index", None)
        if end_actual is None:
            _, end_actual, _ = section  # fallback for tuple-style data
        aligned_pos = bisect_right(aligned_actual_indices, int(end_actual)) - 1
        if aligned_pos < 0:
            raise ValueError(
                f"Tempo section end {end_actual} precedes all aligned reference notes."
            )
        boundaries.append(aligned_pos)
    return boundaries


def score_boundaries(
    predicted: Sequence[int], truth: Sequence[int], tolerance: int = 3
) -> Dict[str, float]:
    if not predicted and not truth:
        return {"precision": 1.0, "recall": 1.0, "f1": 1.0}
    if not predicted or not truth:
        return {"precision": 0.0, "recall": 0.0, "f1": 0.0}
    matched_truth = set()
    matched_pred = set()
    for p_idx, boundary in enumerate(predicted):
        for t_idx, truth_boundary in enumerate(truth):
            if t_idx in matched_truth:
                continue
            if abs(boundary - truth_boundary) <= tolerance:
                matched_pred.add(p_idx)
                matched_truth.add(t_idx)
                break
    precision = len(matched_pred) / len(predicted) if predicted else 0.0
    recall = len(matched_truth) / len(truth) if truth else 0.0
    if precision + recall == 0.0:
        f1 = 0.0
    else:
        f1 = 2 * precision * recall / (precision + recall)
    return {"precision": precision, "recall": recall, "f1": f1}

# %%
PARAM_GRID = {
    "min_segment_length": [6, 8, 10, 12],
    "penalty": [2.0, 3.5, 5.0, 6.5],
    "smoothing_window": [3, 5, 7, 9],
    "max_segments": [None, 6, 8, 10],
}


def evaluate_param_grid(
    datasets: Sequence[TempoDataset],
    grid: Dict[str, Sequence[float | int | None]],
    *,
    tolerance: int = 3,
) -> List[Dict[str, float]]:
    trials: List[Dict[str, float]] = []
    products = itertools.product(
        grid["min_segment_length"],
        grid["penalty"],
        grid["smoothing_window"],
        grid["max_segments"],
    )
    for min_len, penalty, window, max_segments in products:
        params = scoring_native.TempoSegmentationParams(
            min_segment_length=int(min_len),
            penalty=float(penalty),
            smoothing_window=int(window),
            max_segments=None if max_segments is None else int(max_segments),
        )
        precision_scores: List[float] = []
        recall_scores: List[float] = []
        f1_scores: List[float] = []
        instabilities: List[float] = []
        for ds in datasets:
            sections, instability = analyze_tempo(
                ds.actual_times,
                ds.played_times,
                ds.aligned_pairs,
                params,
            )
            predicted_boundaries = boundaries_from_sections(
                sections,
                ds.aligned_actual_indices,
            )
            scores = score_boundaries(
                predicted_boundaries, ds.boundaries, tolerance=tolerance
            )
            precision_scores.append(scores["precision"])
            recall_scores.append(scores["recall"])
            f1_scores.append(scores["f1"])
            instabilities.append(float(instability))
        trials.append(
            {
                "min_segment_length": float(min_len),
                "penalty": float(penalty),
                "smoothing_window": float(window),
                "max_segments": -1.0 if max_segments is None else float(max_segments),
                "precision": float(np.mean(precision_scores)),
                "recall": float(np.mean(recall_scores)),
                "f1": float(np.mean(f1_scores)),
                "instability": float(np.mean(instabilities)),
            }
        )
    trials.sort(
        key=lambda row: (row["f1"], row["precision"], -row["instability"]), reverse=True
    )
    return trials


grid_results = evaluate_param_grid(datasets, PARAM_GRID)
grid_results[:5]
# Out:
# 2025-09-28 15:51:07.252 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.312 ms
# 2025-09-28 15:51:07.319 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.935 ms
# 2025-09-28 15:51:07.386 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.868 ms
# 2025-09-28 15:51:07.452 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.609 ms
# 2025-09-28 15:51:07.518 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.780 ms
# 2025-09-28 15:51:07.585 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.028 ms
# 2025-09-28 15:51:07.653 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.188 ms
# 2025-09-28 15:51:07.720 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.270 ms
# 2025-09-28 15:51:07.786 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.483 ms
# 2025-09-28 15:51:07.853 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.473 ms
# 2025-09-28 15:51:07.921 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.292 ms
# 2025-09-28 15:51:07.989 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.848 ms
# 2025-09-28 15:51:08.056 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.157 ms
# 2025-09-28 15:51:08.124 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.782 ms
# 2025-09-28 15:51:08.193 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.159 ms
# 2025-09-28 15:51:08.261 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.506 ms
# 2025-09-28 15:51:08.326 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.758 ms
# 2025-09-28 15:51:08.393 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.934 ms
# 2025-09-28 15:51:08.459 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.502 ms
# 2025-09-28 15:51:08.525 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.928 ms
# 2025-09-28 15:51:08.591 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.921 ms
# 2025-09-28 15:51:08.659 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.827 ms
# 2025-09-28 15:51:08.725 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.060 ms
# 2025-09-28 15:51:08.792 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.229 ms
# 2025-09-28 15:51:08.858 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.611 ms
# 2025-09-28 15:51:08.925 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.555 ms
# 2025-09-28 15:51:08.992 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.298 ms
# 2025-09-28 15:51:09.059 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.886 ms
# 2025-09-28 15:51:09.126 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.488 ms
# 2025-09-28 15:51:09.195 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.276 ms
# 2025-09-28 15:51:09.263 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.574 ms
# 2025-09-28 15:51:09.331 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.294 ms
# 2025-09-28 15:51:09.396 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.946 ms
# 2025-09-28 15:51:09.462 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.687 ms
# 2025-09-28 15:51:09.528 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.731 ms
# 2025-09-28 15:51:09.594 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.412 ms
# 2025-09-28 15:51:09.660 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.714 ms
# 2025-09-28 15:51:09.727 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.368 ms
# 2025-09-28 15:51:09.794 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.778 ms
# 2025-09-28 15:51:09.861 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.057 ms
# 2025-09-28 15:51:09.928 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.988 ms
# 2025-09-28 15:51:09.995 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.428 ms
# 2025-09-28 15:51:10.062 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.394 ms
# 2025-09-28 15:51:10.130 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.694 ms
# 2025-09-28 15:51:10.197 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.116 ms
# 2025-09-28 15:51:10.265 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.552 ms
# 2025-09-28 15:51:10.333 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.153 ms
# 2025-09-28 15:51:10.401 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.348 ms
# 2025-09-28 15:51:10.466 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.606 ms
# 2025-09-28 15:51:10.533 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.843 ms
# 2025-09-28 15:51:10.599 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.545 ms
# 2025-09-28 15:51:10.665 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.059 ms
# 2025-09-28 15:51:10.732 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.888 ms
# 2025-09-28 15:51:10.799 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.303 ms
# 2025-09-28 15:51:10.866 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.025 ms
# 2025-09-28 15:51:10.933 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.476 ms
# 2025-09-28 15:51:10.999 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.774 ms
# 2025-09-28 15:51:11.067 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.192 ms
# 2025-09-28 15:51:11.134 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.791 ms
# 2025-09-28 15:51:11.204 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.715 ms
# 2025-09-28 15:51:11.272 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.620 ms
# 2025-09-28 15:51:11.339 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.061 ms
# 2025-09-28 15:51:11.407 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.370 ms
# 2025-09-28 15:51:11.475 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.537 ms
# 2025-09-28 15:51:11.540 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.390 ms
# 2025-09-28 15:51:11.606 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.005 ms
# 2025-09-28 15:51:11.672 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.768 ms
# 2025-09-28 15:51:11.738 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.855 ms
# 2025-09-28 15:51:11.804 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.404 ms
# 2025-09-28 15:51:11.870 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.519 ms
# 2025-09-28 15:51:11.936 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.881 ms
# 2025-09-28 15:51:12.002 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.628 ms
# 2025-09-28 15:51:12.069 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.992 ms
# 2025-09-28 15:51:12.136 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.583 ms
# 2025-09-28 15:51:12.204 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.434 ms
# 2025-09-28 15:51:12.271 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.503 ms
# 2025-09-28 15:51:12.337 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.203 ms
# 2025-09-28 15:51:12.405 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.256 ms
# 2025-09-28 15:51:12.474 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.486 ms
# 2025-09-28 15:51:12.543 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.139 ms
# 2025-09-28 15:51:12.607 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.407 ms
# 2025-09-28 15:51:12.673 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.561 ms
# 2025-09-28 15:51:12.740 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.115 ms
# 2025-09-28 15:51:12.806 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.546 ms
# 2025-09-28 15:51:12.871 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.905 ms
# 2025-09-28 15:51:12.938 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.991 ms
# 2025-09-28 15:51:13.004 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.185 ms
# 2025-09-28 15:51:13.072 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.727 ms
# 2025-09-28 15:51:13.138 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.834 ms
# 2025-09-28 15:51:13.206 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.439 ms
# 2025-09-28 15:51:13.273 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.600 ms
# 2025-09-28 15:51:13.340 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.328 ms
# 2025-09-28 15:51:13.406 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.006 ms
# 2025-09-28 15:51:13.474 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.002 ms
# 2025-09-28 15:51:13.541 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.151 ms
# 2025-09-28 15:51:13.609 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.259 ms
# 2025-09-28 15:51:13.675 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.158 ms
# 2025-09-28 15:51:13.742 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.134 ms
# 2025-09-28 15:51:13.808 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.510 ms
# 2025-09-28 15:51:13.874 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.069 ms
# 2025-09-28 15:51:13.939 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.374 ms
# 2025-09-28 15:51:14.005 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.448 ms
# 2025-09-28 15:51:14.072 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.311 ms
# 2025-09-28 15:51:14.139 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.798 ms
# 2025-09-28 15:51:14.207 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.389 ms
# 2025-09-28 15:51:14.274 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.755 ms
# 2025-09-28 15:51:14.341 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.568 ms
# 2025-09-28 15:51:14.409 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.794 ms
# 2025-09-28 15:51:14.476 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.192 ms
# 2025-09-28 15:51:14.543 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.825 ms
# 2025-09-28 15:51:14.610 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.727 ms
# 2025-09-28 15:51:14.678 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.468 ms
# 2025-09-28 15:51:14.744 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.119 ms
# 2025-09-28 15:51:14.810 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.786 ms
# 2025-09-28 15:51:14.876 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.310 ms
# 2025-09-28 15:51:14.943 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.012 ms
# 2025-09-28 15:51:15.008 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.043 ms
# 2025-09-28 15:51:15.075 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.155 ms
# 2025-09-28 15:51:15.141 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.650 ms
# 2025-09-28 15:51:15.208 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.878 ms
# 2025-09-28 15:51:15.275 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.824 ms
# 2025-09-28 15:51:15.342 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.462 ms
# 2025-09-28 15:51:15.409 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.593 ms
# 2025-09-28 15:51:15.475 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.445 ms
# 2025-09-28 15:51:15.542 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.447 ms
# 2025-09-28 15:51:15.610 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.153 ms
# 2025-09-28 15:51:15.678 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.661 ms
# 2025-09-28 15:51:15.746 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.300 ms
# 2025-09-28 15:51:15.811 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.593 ms
# 2025-09-28 15:51:15.876 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.942 ms
# 2025-09-28 15:51:15.942 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.196 ms
# 2025-09-28 15:51:16.007 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.780 ms
# 2025-09-28 15:51:16.073 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.165 ms
# 2025-09-28 15:51:16.139 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.393 ms
# 2025-09-28 15:51:16.206 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.437 ms
# 2025-09-28 15:51:16.273 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.546 ms
# 2025-09-28 15:51:16.339 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.642 ms
# 2025-09-28 15:51:16.405 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.194 ms
# 2025-09-28 15:51:16.473 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.578 ms
# 2025-09-28 15:51:16.540 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.384 ms
# 2025-09-28 15:51:16.607 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.130 ms
# 2025-09-28 15:51:16.675 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.552 ms
# 2025-09-28 15:51:16.743 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.866 ms
# 2025-09-28 15:51:16.811 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.867 ms
# 2025-09-28 15:51:16.876 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.262 ms
# 2025-09-28 15:51:16.942 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.347 ms
# 2025-09-28 15:51:17.008 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.282 ms
# 2025-09-28 15:51:17.074 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.381 ms
# 2025-09-28 15:51:17.139 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.722 ms
# 2025-09-28 15:51:17.206 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.132 ms
# 2025-09-28 15:51:17.272 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.078 ms
# 2025-09-28 15:51:17.338 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.698 ms
# 2025-09-28 15:51:17.404 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.639 ms
# 2025-09-28 15:51:17.471 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.503 ms
# 2025-09-28 15:51:17.538 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.024 ms
# 2025-09-28 15:51:17.606 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.387 ms
# 2025-09-28 15:51:17.672 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.162 ms
# 2025-09-28 15:51:17.741 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 68.083 ms
# 2025-09-28 15:51:17.808 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.020 ms
# 2025-09-28 15:51:17.876 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.723 ms
# 2025-09-28 15:51:17.940 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.096 ms
# 2025-09-28 15:51:18.006 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.312 ms
# 2025-09-28 15:51:18.072 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.565 ms
# 2025-09-28 15:51:18.137 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.017 ms
# 2025-09-28 15:51:18.203 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.368 ms
# 2025-09-28 15:51:18.270 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.361 ms
# 2025-09-28 15:51:18.336 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.929 ms
# 2025-09-28 15:51:18.403 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.794 ms
# 2025-09-28 15:51:18.469 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.944 ms
# 2025-09-28 15:51:18.535 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.047 ms
# 2025-09-28 15:51:18.602 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.417 ms
# 2025-09-28 15:51:18.669 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.436 ms
# 2025-09-28 15:51:18.736 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.643 ms
# 2025-09-28 15:51:18.804 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.894 ms
# 2025-09-28 15:51:18.871 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.848 ms
# 2025-09-28 15:51:18.938 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.599 ms
# 2025-09-28 15:51:19.003 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.467 ms
# 2025-09-28 15:51:19.069 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.242 ms
# 2025-09-28 15:51:19.134 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.039 ms
# 2025-09-28 15:51:19.201 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.016 ms
# 2025-09-28 15:51:19.267 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.325 ms
# 2025-09-28 15:51:19.333 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.945 ms
# 2025-09-28 15:51:19.399 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.577 ms
# 2025-09-28 15:51:19.465 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.912 ms
# 2025-09-28 15:51:19.532 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.652 ms
# 2025-09-28 15:51:19.598 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.396 ms
# 2025-09-28 15:51:19.665 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.056 ms
# 2025-09-28 15:51:19.732 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.971 ms
# 2025-09-28 15:51:19.799 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.519 ms
# 2025-09-28 15:51:19.867 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.977 ms
# 2025-09-28 15:51:19.934 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.791 ms
# 2025-09-28 15:51:20.001 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.574 ms
# 2025-09-28 15:51:20.066 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 63.977 ms
# 2025-09-28 15:51:20.131 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.174 ms
# 2025-09-28 15:51:20.197 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.182 ms
# 2025-09-28 15:51:20.262 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.101 ms
# 2025-09-28 15:51:20.328 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.695 ms
# 2025-09-28 15:51:20.394 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.410 ms
# 2025-09-28 15:51:20.459 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.156 ms
# 2025-09-28 15:51:20.525 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.024 ms
# 2025-09-28 15:51:20.590 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.095 ms
# 2025-09-28 15:51:20.661 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 70.386 ms
# 2025-09-28 15:51:20.728 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.538 ms
# 2025-09-28 15:51:20.795 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.757 ms
# 2025-09-28 15:51:20.861 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.840 ms
# 2025-09-28 15:51:20.928 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.435 ms
# 2025-09-28 15:51:20.995 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.414 ms
# 2025-09-28 15:51:21.062 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.398 ms
# 2025-09-28 15:51:21.127 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.083 ms
# 2025-09-28 15:51:21.192 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.065 ms
# 2025-09-28 15:51:21.258 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.870 ms
# 2025-09-28 15:51:21.324 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.918 ms
# 2025-09-28 15:51:21.389 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.600 ms
# 2025-09-28 15:51:21.455 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.783 ms
# 2025-09-28 15:51:21.521 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.307 ms
# 2025-09-28 15:51:21.587 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.770 ms
# 2025-09-28 15:51:21.653 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.142 ms
# 2025-09-28 15:51:21.721 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.053 ms
# 2025-09-28 15:51:21.788 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.631 ms
# 2025-09-28 15:51:21.854 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.186 ms
# 2025-09-28 15:51:21.920 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.560 ms
# 2025-09-28 15:51:21.987 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.592 ms
# 2025-09-28 15:51:22.054 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.737 ms
# 2025-09-28 15:51:22.122 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.760 ms
# 2025-09-28 15:51:22.186 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.006 ms
# 2025-09-28 15:51:22.253 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.556 ms
# 2025-09-28 15:51:22.318 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.936 ms
# 2025-09-28 15:51:22.384 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.159 ms
# 2025-09-28 15:51:22.450 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.556 ms
# 2025-09-28 15:51:22.518 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.010 ms
# 2025-09-28 15:51:22.584 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.350 ms
# 2025-09-28 15:51:22.650 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.348 ms
# 2025-09-28 15:51:22.715 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.210 ms
# 2025-09-28 15:51:22.783 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.946 ms
# 2025-09-28 15:51:22.850 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.205 ms
# 2025-09-28 15:51:22.917 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.930 ms
# 2025-09-28 15:51:22.983 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.316 ms
# 2025-09-28 15:51:23.050 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.298 ms
# 2025-09-28 15:51:23.117 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.615 ms
# 2025-09-28 15:51:23.183 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.137 ms
# 2025-09-28 15:51:23.249 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.991 ms
# 2025-09-28 15:51:23.315 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.534 ms
# 2025-09-28 15:51:23.381 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.973 ms
# 2025-09-28 15:51:23.447 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.879 ms
# 2025-09-28 15:51:23.512 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 64.670 ms
# 2025-09-28 15:51:23.578 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.431 ms
# 2025-09-28 15:51:23.645 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.667 ms
# 2025-09-28 15:51:23.711 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.630 ms
# 2025-09-28 15:51:23.777 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 65.626 ms
# 2025-09-28 15:51:23.845 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.259 ms
# 2025-09-28 15:51:23.934 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 88.827 ms
# 2025-09-28 15:51:24.004 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.490 ms
# 2025-09-28 15:51:24.073 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.838 ms
# 2025-09-28 15:51:24.141 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.137 ms
# 2025-09-28 15:51:24.208 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 66.526 ms
# 2025-09-28 15:51:24.276 | INFO     | __main__:evaluate_param_grid:33 - 	[analyze_tempo] took 67.283 ms
# [{'min_segment_length': 6.0,
#   'penalty': 2.0,
#   'smoothing_window': 9.0,
#   'max_segments': -1.0,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672},
#  {'min_segment_length': 6.0,
#   'penalty': 2.0,
#   'smoothing_window': 9.0,
#   'max_segments': 6.0,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672},
#  {'min_segment_length': 6.0,
#   'penalty': 2.0,
#   'smoothing_window': 9.0,
#   'max_segments': 8.0,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672},
#  {'min_segment_length': 6.0,
#   'penalty': 2.0,
#   'smoothing_window': 9.0,
#   'max_segments': 10.0,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672},
#  {'min_segment_length': 6.0,
#   'penalty': 3.5,
#   'smoothing_window': 9.0,
#   'max_segments': -1.0,
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672}]

# %%
best = grid_results[0]
best
# Out:
# {'min_segment_length': 6.0,
#  'penalty': 2.0,
#  'smoothing_window': 9.0,
#  'max_segments': -1.0,
#  'precision': 0.0,
#  'recall': 0.0,
#  'f1': 0.0,
#  'instability': 170.4219207763672}

# %%
def params_from_row(row: Dict[str, float]) -> scoring_native.TempoSegmentationParams:
    max_segments = None if row["max_segments"] < 0 else int(row["max_segments"])
    return scoring_native.TempoSegmentationParams(
        min_segment_length=int(row["min_segment_length"]),
        penalty=float(row["penalty"]),
        smoothing_window=int(row["smoothing_window"]),
        max_segments=max_segments,
    )


best_params = params_from_row(best)
per_dataset_scores: List[Dict[str, float]] = []
for ds in datasets:
    sections, instability = analyze_tempo(
        ds.actual_times,
        ds.played_times,
        ds.aligned_pairs,
        best_params,
    )
    predicted_boundaries = boundaries_from_sections(
        sections,
        ds.aligned_actual_indices,
    )
    scores = score_boundaries(predicted_boundaries, ds.boundaries)
    per_dataset_scores.append(
        {
            "title": ds.title,
            "precision": scores["precision"],
            "recall": scores["recall"],
            "f1": scores["f1"],
            "instability": float(instability),
        }
    )
per_dataset_scores
# Out:
# 2025-09-28 15:51:24.390 | INFO     | __main__:<module>:13 - 	[analyze_tempo] took 66.811 ms
# [{'title': 'Spider Dance Take 1',
#   'precision': 0.0,
#   'recall': 0.0,
#   'f1': 0.0,
#   'instability': 170.4219207763672}]

# %%
OUTPUT_PATH = DATA_PATH.with_suffix(".fitted_params.json")
payload = {
    "params": {
        "min_segment_length": best_params.min_segment_length,
        "penalty": best_params.penalty,
        "smoothing_window": best_params.smoothing_window,
        "max_segments": best_params.max_segments,
    },
    "aggregate_scores": {
        "precision": best["precision"],
        "recall": best["recall"],
        "f1": best["f1"],
        "instability": best["instability"],
    },
    "per_dataset": per_dataset_scores,
    "grid_top": grid_results[:10],
}
OUTPUT_PATH.write_text(json.dumps(payload, indent=2))
OUTPUT_PATH
# Out:
# PosixPath('fit_tempo_dataset.fitted_params.json')
